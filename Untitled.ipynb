# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("loan-train.csv")

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.shape
# Out:
# (614, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
cl = df.columns

# %%
for i in cl:
    print("Column name",i)
    print(df[i].unique())
    print("="*80)
# Out:
# Column name Loan_ID
# ['LP001002' 'LP001003' 'LP001005' 'LP001006' 'LP001008' 'LP001011'
#  'LP001013' 'LP001014' 'LP001018' 'LP001020' 'LP001024' 'LP001027'
#  'LP001028' 'LP001029' 'LP001030' 'LP001032' 'LP001034' 'LP001036'
#  'LP001038' 'LP001041' 'LP001043' 'LP001046' 'LP001047' 'LP001050'
#  'LP001052' 'LP001066' 'LP001068' 'LP001073' 'LP001086' 'LP001087'
#  'LP001091' 'LP001095' 'LP001097' 'LP001098' 'LP001100' 'LP001106'
#  'LP001109' 'LP001112' 'LP001114' 'LP001116' 'LP001119' 'LP001120'
#  'LP001123' 'LP001131' 'LP001136' 'LP001137' 'LP001138' 'LP001144'
#  'LP001146' 'LP001151' 'LP001155' 'LP001157' 'LP001164' 'LP001179'
#  'LP001186' 'LP001194' 'LP001195' 'LP001197' 'LP001198' 'LP001199'
#  'LP001205' 'LP001206' 'LP001207' 'LP001213' 'LP001222' 'LP001225'
#  'LP001228' 'LP001233' 'LP001238' 'LP001241' 'LP001243' 'LP001245'
#  'LP001248' 'LP001250' 'LP001253' 'LP001255' 'LP001256' 'LP001259'
#  'LP001263' 'LP001264' 'LP001265' 'LP001266' 'LP001267' 'LP001273'
# ...

# %%
for i in cl:
    print(i)
    print(df[i].isnull().sum())
    print("="*50)
# Out:
# Loan_ID
# 0
# ...
# Gender
# 13
# ...
# Married
# 3
# ...
# Dependents
# 15
# ...
# Education
# 0
# ...
# Self_Employed
# 32
# ...
# ApplicantIncome
# 0
# ...
# CoapplicantIncome
# 0
# ...
# LoanAmount
# 22
# ...
# Loan_Amount_Term
# 14
# ...
# Credit_History
# 50
# ...
# Property_Area
# 0
# ...
# Loan_Status
# 0
# ...

# %%
for i in cl:
    print(i)
    print(df[i].describe())
    print("========================================")
# Out:
# Loan_ID
# count          614
# unique         614
# top       LP001002
# freq             1
# Name: Loan_ID, dtype: object
# ...
# Gender
# count      601
# unique       2
# top       Male
# freq       489
# Name: Gender, dtype: object
# ...
# Married
# count     611
# unique      2
# top       Yes
# freq      398
# Name: Married, dtype: object
# ...
# Dependents
# count     599
# unique      4
# top         0
# freq      345
# Name: Dependents, dtype: object
# ...
# Education
# count          614
# unique           2
# top       Graduate
# freq           480
# Name: Education, dtype: object
# ...
# Self_Employed
# count     582
# unique      2
# top        No
# freq      500
# Name: Self_Employed, dtype: object
# ...
# ApplicantIncome
# count      614.000000
# mean      5403.459283
# std       6109.041673
# min        150.000000
# 25%       2877.500000
# 50%       3812.500000
# 75%       5795.000000
# max      81000.000000
# Name: ApplicantIncome, dtype: float64
# ...
# CoapplicantIncome
# count      614.000000
# ...

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df['Gender'].isnull().sum()
# Out:
# 13

# %%
df['Gender'].value_counts()
# Out:
# Male      489
# Female    112
# Name: Gender, dtype: int64

# %%
df[df.duplicated()] #no duplicated values
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status]
# Index: []

# %%
mode_category = df['Gender'].mode()[0]

# %%
mode_category
# Out:
# 'Male'

# %%
df['Gender'].fillna(mode_category, inplace=True)

# %%
df['Gender'].isnull().sum()
# Out:
# 0

# %%
mode_category_Married= df['Married'].mode()[0]
mode_category_Married
# Out:
# 'Yes'

# %%
df['Married'].fillna(mode_category_Married, inplace=True)
df['Married'].isnull().sum()
# Out:
# 0

# %%
mode_category_Dependents= df['Dependents'].mode()[0]
mode_category_Dependents
# Out:
# '0'

# %%
df['Dependents'].fillna(mode_category_Dependents, inplace=True)
df['Dependents'].isnull().sum()
# Out:
# 0

# %%
mode_category_Self_Employed= df['Self_Employed'].mode()[0]
mode_category_Self_Employed
# Out:
# 'No'

# %%
df['Self_Employed'].fillna(mode_category_Self_Employed, inplace=True)
df['Self_Employed'].isnull().sum()
# Out:
# 0

# %%
#Mapping
gender_mapping = {'Male': 0, 'Female': 1}

# %%
df['Gender'].replace(gender_mapping, inplace=True)

# %%
Married_mapping={'Yes':0,'No':1}

# %%
df['Married'].replace(Married_mapping, inplace=True)

# %%
gender_Education = {'Graduate':0 ,'Not Graduate':1}
df['Education'].replace(gender_Education, inplace=True)

# %%
Self_Employed_mapping= {'Yes':0,'No':1}
df['Self_Employed'].replace(Self_Employed_mapping, inplace=True)

# %%
Property_Area_mapping= {'Urban':0, 'Rural':1, 'Semiurban':2}
df['Property_Area'].replace(Property_Area_mapping, inplace=True)

# %%
Dependents_mapping= {'3+':3}
df['Dependents'].replace(Dependents_mapping, inplace=True)

# %%
Loan_Status_mapping= {'Y':0, 'N':1}
df['Loan_Status'].replace(Loan_Status_mapping, inplace=True)

# %%
df.fillna(0, inplace=True)

# %%
df.head()
# Out:
#    Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       0        1          0          0              1             5849
# 1       0        0          1          0              1             4583
# 2       0        0          0          0              0             3000
# 3       0        0          0          1              1             2583
# 4       0        1          0          0              1             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         0.0             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#    Property_Area  Loan_Status
# 0              0            0
# 1              1            1
# ...

# %%
df.drop('Loan_ID', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[202], line 1
# ----> 1 df.drop('Loan_ID', axis=1, inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
# Correlation
sns.heatmap(df.corr(),annot=True)
# Out:
# C:\Users\ROCKSTAR\AppData\Local\Temp\ipykernel_6328\1921210434.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %%
X=df.drop(labels=['Loan_Status'],axis=1)
y = df[['Loan_Status']]

# %%
from sklearn.model_selection import train_test_split

# %%
# i.e. 70 % training dataset and 30 % test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30)

# %%
# importing random forest classifier from assemble module
from sklearn.ensemble import RandomForestClassifier

# %%
X_train.head()
# Out:
#      Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 247       0        0          1          1              1             6608
# 422       0        0          0          0              1             1820
# 104       0        0          0          0              1             3816
# 255       1        1          3          0              1             3083
# 271       0        0          0          0              1            11146
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 247                0.0       137.0             180.0             1.0
# 422             1719.0       100.0             360.0             1.0
# 104              754.0       160.0             360.0             1.0
# 255                0.0       255.0             360.0             1.0
# 271                0.0       136.0             360.0             1.0
#
#      Property_Area
# 247              0
# 422              0
# 104              0
# ...

# %%
# creating a RF classifier
random_forest_c= RandomForestClassifier(n_estimators = 100)  
  
# Training the model on the training dataset
# fit function is used to train the model using the training sets as parameters
random_forest_c.fit(X_train, y_train)
  
# performing predictions on the test dataset
y_pred = random_forest_c.predict(X_test)
  
# metrics are used to find accuracy or error
from sklearn import metrics  
print()
  
# using metrics module for accuracy calculation
print("ACCURACY OF THE MODEL: ", metrics.accuracy_score(y_test, y_pred))
# Out:
# C:\Users\ROCKSTAR\AppData\Local\Temp\ipykernel_6328\375558668.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   random_forest_c.fit(X_train, y_train)
# ACCURACY OF THE MODEL:  0.7513513513513513

# %%
from sklearn.linear_model import LogisticRegression
logestic_regression=LogisticRegression(random_state=None)
logestic_regression.fit(X_train,y_train)
y_pred=logestic_regression.predict(X_test)
print("ACCURACY OF THE MODEL: ", metrics.accuracy_score(y_test, y_pred))
# Out:
# ACCURACY OF THE MODEL:  0.7945945945945946
# C:\Users\ROCKSTAR\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn.tree import DecisionTreeClassifier
design_tree=DecisionTreeClassifier()
design_tree.fit(X_train,y_train)
y_pred=design_tree.predict(X_test)
print("ACCURACY OF THE MODEL: ", metrics.accuracy_score(y_test, y_pred))
# Out:
# ACCURACY OF THE MODEL:  0.6810810810810811
